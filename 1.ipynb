# %%
import re   # python 的正则库
import requests     # python 的requests库
import time

headers ={
"user-agent": "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3947.100 Safari/537.36"
}

# page=int(input("请输入您要爬取的页数："))

songID=[]
songName=[]
page =1  # int(input("请输入要下载多少页"))
for i in range(0,page):
	url="http://www.htqyy.com/top/musicList/hot?pageIndex="+str(i)+"&pageSize=20"

	#获取音乐榜单的网页信息
	html=requests.get(url=url,headers=headers)

	strr=html.text

	pat1=r'title="(.*?)"'
	pat2=r'sid="(.*?)"'

	idlist=re.findall(pat2,strr)
	titlelist=re.findall(pat1,strr)
	songID.extend(idlist)
	songName.extend(titlelist)
	print(len(songID))

for i in range(0,len(songID)):
	songurl="http://f2.htqyy.com/play7/"+str(songID[i])+"/mp3/2"
	songname=songName[i]

	data=requests.get(songurl).content

	print("正在下载第",i+1,"首")

	with open("D:\\music\\{}.mp3".format(songname),"wb") as f:
		f.write(data)

	time.sleep(0.5)
# Out:
# 0

# %%
time=0
while(time<=32767):
    print("nircmd.exe setsysvolume "+str(time)+"\n")
    time=time+1

# %%
import requests
sfs=['340825200503122444','340825200408282415','340825200411202420','340825200406192424','340825200507312421','340825200507092422','340825200411172428','340825200410252426','340825200509202410','340825200508292418','340825200502282411','340825200406102417','340825200408132417','340825200501132411','34082520030813241X','340825200508182438','340825200507202417','340825200508312431','340825200501302417','34082520041205241X','340825200411102411','340825200408032424','340825200508272425','340825200412242424','340825200507102424','340825200508302428','340825200502242428','340825200507022440','340825200507022424','340825200505252429','340825200511292427','340825200507052420','34082520060529241X','340825200412302431','340825200410062446','340825200512202411']
khs=203082500458
t=0
ti=40
s=0

def postHttp(sf,kh):
    url="http://218.22.132.6:9988/cjcx/cxjg.asp"
    #定义要提交的数据
    postdata=dict(i_sfzh=sf,i_kh=kh)
    #url编码
    time=0
    times=0
    #enable cookie
    response=requests.post(url,postdata)
    #print(response.text) 
    text=response.text
    te=''
    text=text.rsplit('<td class="tdclass2">')
    for i in text:
        time=time+1
        if(time==3):
            a=i.rsplit('<td class="tdclass1">',maxsplit=1)
            for b in a:
                times=times+1
                if(times==1):
                    print(b+"\n") 

for sf in sfs:
     while(t<=ti):
         t=t+1
         kh=khs+t
         postHttp(sf,kh)
     t=0
# Out:
# 525</td>
#
#
# 370</td>
#
#
# 476.5</td>
#
#
# 618.5</td>
#
#
# 528.5</td>
#
#
# 637.5</td>
#
#
# 487.5</td>
#
#
# 621</td>
#
#
# 441.5</td>
#
#
# 584</td>
#
#
# 522</td>
#
#
# 563.5</td>
#
#
# 640</td>
#
#
# 341.5</td>
#
#
# 668.5</td>
#
#
# 477.5</td>
#
#
# 612</td>
#
#
# 674.5</td>
#
#
# 596.5</td>
#
#
# 588</td>
#
#
# 658.5</td>
#
#
# 412.5</td>
#
#
# 562.5</td>
#
#
# 313</td>
#
#
# 597.5</td>
#
#
# 578.5</td>
#
#
# 553.5</td>
#
#
# 484</td>
#
#
# 505</td>
#
#
# 576</td>
#
#
# 608.5</td>
#
#
# 510</td>
#
#
# 618</td>
#
#
# 664</td>

# %%
import random

# 魔方数组创建
a = ["a1", "a2", "a3", "a4", "a5", "a6", "a7", "a8", "a9"]
b = ["b1", "b2", "b3", "b4", "b5", "b6", "b7", "b8", "b9"]
c = ["c1", "c2", "c3", "c4", "c5", "c6", "c7", "c8", "c9"]
d = ["d1", "d2", "d3", "d4", "d5", "d6", "d7", "d8", "d9"]
e = ["e1", "e2", "e3", "e4", "e5", "e6", "e7", "e8", "e9"]
f = ["f1", "f2", "f3", "f4", "f5", "f6", "f7", "f8", "f9"]

step = []  # 储存魔方转动步骤
run_num = 0
q=False
re=0


def originate():
    global a, b, c, d, e, f, step,run_num
    # 魔方数组创建
    a = ["a1", "a2", "a3", "a4", "a5", "a6", "a7", "a8", "a9"]
    b = ["b1", "b2", "b3", "b4", "b5", "b6", "b7", "b8", "b9"]
    c = ["c1", "c2", "c3", "c4", "c5", "c6", "c7", "c8", "c9"]
    d = ["d1", "d2", "d3", "d4", "d5", "d6", "d7", "d8", "d9"]
    e = ["e1", "e2", "e3", "e4", "e5", "e6", "e7", "e8", "e9"]
    f = ["f1", "f2", "f3", "f4", "f5", "f6", "f7", "f8", "f9"]

    step = []  # 储存魔方转动步骤
    run_num=0


def processing_random_steps(num_steps):
    time = 0
    while (time <= num_steps):
        global a, b, d, c, e, f, step
        step_tmp = random.randint(1, 9)
        step.append(step_tmp)
        time = time + 1


def check_ok():
    if (a[0] == 'a1' and a[1] == 'a2' and a[2] == 'a3' and a[3] == 'a4' and a[4] == 'a5' and a[5] == 'a6' and a[
        8] == 'a9' and a[6] == 'a7' and a[8] == 'a9'):
        if (b[0] == 'b1' and b[1] == 'b2' and b[2] == 'b3' and b[3] == 'b4' and b[4] == 'b5' and b[5] == 'b6' and b[
            8] == 'b9' and b[6] == 'b7' and b[8] == 'b9'):
            if (c[0] == 'c1' and c[1] == 'c2' and c[2] == 'c3' and c[3] == 'c4' and c[4] == 'c5' and c[5] == 'c6' and c[
                8] == 'c9' and c[6] == 'c7' and c[8] == 'c9'):
                if (d[0] == 'd1' and d[1] == 'd2' and d[2] == 'd3' and d[3] == 'd4' and d[4] == 'd5' and d[
                    5] == 'd6' and d[8] == 'd9' and d[6] == 'd7' and d[8] == 'd9'):
                    if (e[0] == 'e1' and e[1] == 'e2' and e[2] == 'e3' and e[3] == 'e4' and e[4] == 'e5' and e[
                        5] == 'e6' and e[8] == 'e9' and e[6] == 'e7' and e[8] == 'e9'):
                        if (f[0] == 'f1' and f[1] == 'f2' and f[2] == 'f3' and f[3] == 'f4' and f[4] == 'f5' and f[
                            5] == 'f6' and f[8] == 'f9' and f[6] == 'f7' and f[8] == 'f9'):
                            return True


def prove(times=random.randint(1, 500)):
    time = 0
    success = 0
    run_num=0
    while time < times:
        time = time + 1
        originate()
        num_steps = random.randint(1, 50)
        processing_random_steps(num_steps)
        run(step)
        while not (check_ok()):
            run(step)
            run_num = run_num + 1
        if check_ok():
            success = success + 1
            print("重复" + str(run_num+1) + "次转动程序后成功，一共转动" + str((run_num+1) * len(step)) + "次，本次转动程序代号为" + str(step))
            run_num=0
    print("本次证明程序运行共" + str(times) + "次，其中成功" + str(success) + "次")


def run(step):
    for i in step:
        if (i == 1):
            tmp = c[0]
            c[0] = b[0]
            b[0] = d[0]
            d[0] = a[0]
            a[0] = tmp
            tmp = c[1]
            c[1] = b[1]
            b[1] = d[1]
            d[1] = a[1]
            a[1] = tmp
            tmp = c[2]
            c[2] = b[2]
            b[2] = d[2]
            d[2] = a[2]
            a[2] = tmp
            tmp = f[0]
            f[0] = f[2]
            f[2] = f[8]
            f[8] = f[6]
            f[6] = tmp
            tmp = f[1]
            f[1] = f[5]
            f[5] = f[7]
            f[7] = f[3]
            f[3] = tmp
        if (i == 2):
            tmp = c[3]
            c[3] = b[3]
            b[3] = d[3]
            d[3] = a[3]
            a[3] = tmp
            tmp = c[4]
            c[4] = b[4]
            b[4] = d[4]
            d[4] = a[4]
            a[4] = tmp
            tmp = c[5]
            c[5] = b[5]
            b[5] = d[5]
            d[5] = a[5]
            a[5] = tmp
        if (i == 3):
            tmp = c[6]
            c[6] = b[6]
            b[6] = d[6]
            d[6] = a[6]
            a[6] = tmp
            tmp = c[7]
            c[7] = b[7]
            b[7] = d[7]
            d[7] = a[7]
            a[7] = tmp
            tmp = c[8]
            c[8] = b[8]
            b[8] = d[8]
            d[8] = a[8]
            a[8] = tmp
            tmp = e[0]
            e[0] = e[6]
            e[6] = e[8]
            e[8] = e[2]
            e[2] = tmp
            tmp = e[1]
            e[1] = e[3]
            e[3] = e[7]
            e[7] = e[5]
            e[5] = tmp
        if (i == 4):
            tmp = e[0]
            e[0] = b[8]
            b[8] = f[0]
            f[0] = a[0]
            a[0] = tmp
            tmp = e[3]
            e[3] = b[5]
            b[5] = f[3]
            f[3] = a[3]
            a[3] = tmp
            tmp = e[6]
            e[6] = b[2]
            b[2] = f[6]
            f[6] = a[6]
            a[6] = tmp
            tmp = c[0]
            c[0] = c[2]
            c[2] = c[8]
            c[8] = c[6]
            c[6] = tmp
            tmp = c[1]
            c[1] = c[5]
            c[5] = c[7]
            c[7] = c[3]
            c[3] = tmp
        if (i == 5):
            tmp = e[1]
            e[1] = b[7]
            b[7] = f[1]
            f[1] = a[1]
            a[1] = tmp
            tmp = e[4]
            e[4] = b[4]
            b[4] = f[4]
            f[4] = a[4]
            a[4] = tmp
            tmp = e[7]
            e[7] = b[1]
            b[1] = f[7]
            f[7] = a[7]
            a[7] = tmp
        if (i == 6):
            tmp = e[2]
            e[2] = b[6]
            b[6] = f[2]
            f[2] = a[2]
            a[2] = tmp
            tmp = e[5]
            e[5] = b[3]
            b[3] = f[5]
            f[5] = a[5]
            a[5] = tmp
            tmp = e[8]
            e[8] = b[0]
            b[0] = f[8]
            f[8] = a[8]
            a[8] = tmp
            tmp = d[0]
            d[0] = d[6]
            d[6] = d[8]
            d[8] = d[2]
            d[2] = tmp
            tmp = d[1]
            d[1] = d[3]
            d[3] = d[7]
            d[7] = d[5]
            d[5] = tmp
        if (i == 7):
            tmp = f[6]
            f[6] = d[0]
            d[0] = e[2]
            e[2] = c[8]
            c[8] = tmp
            tmp = f[7]
            f[7] = d[3]
            d[3] = e[1]
            e[1] = c[5]
            c[5] = tmp
            tmp = f[8]
            f[8] = d[6]
            d[6] = e[0]
            e[0] = c[2]
            c[2] = tmp
            tmp = a[0]
            a[0] = a[2]
            a[2] = a[8]
            a[8] = a[6]
            a[6] = tmp
            tmp = a[1]
            a[1] = a[5]
            a[5] = a[7]
            a[7] = a[3]
            a[3] = tmp
        if (i == 8):
            tmp = f[3]
            f[3] = d[1]
            d[1] = e[5]
            e[5] = c[7]
            c[7] = tmp
            tmp = f[4]
            f[4] = d[4]
            d[4] = e[4]
            e[4] = c[4]
            c[4] = tmp
            tmp = f[5]
            f[5] = d[7]
            d[7] = e[3]
            e[3] = c[1]
            c[1] = tmp
        if (i == 9):
            tmp = f[0]
            f[0] = d[2]
            d[2] = e[8]
            e[8] = c[6]
            c[6] = tmp
            tmp = f[1]
            f[1] = d[5]
            d[5] = e[7]
            e[7] = c[3]
            c[3] = tmp
            tmp = f[2]
            f[2] = d[8]
            d[8] = e[6]
            e[6] = c[0]
            c[0] = tmp
            tmp = b[0]
            b[0] = b[6]
            b[6] = b[8]
            b[8] = b[2]
            b[2] = tmp
            tmp = b[1]
            b[1] = b[3]
            b[3] = b[7]
            b[7] = b[5]
            b[5] = tmp


def get_step():
    step_str = input("请输入转动程序步骤，从1-9，用英文逗号隔开   ------->")
    steps = step_str.split(",")
    for i in range(0, len(steps)):
        steps[i] = int(steps[i])
    return steps


def check_get_steps(steps):
    global error, right
    for i in range(0, len(steps)):
        if not (steps[i] <= 9 and steps[i] >= 1):
            print("输入步骤有误，请重新输入")
            error = True
            break
        else:
            right = right + 1
def main_func():
    global q,re
    if (int(mode) == 1):
        times = input("请输入验证次数，直接回车随机生成  ------>")
        if times == '':
            times = random.randint(1, 1000)
        else:
            times = int(times)
        prove(times)
    elif (int(mode) == 2):
        originate()
        fail = True
        error = False
        right = 0
        time = 0
        success = 0
        steps = get_step()
        while fail == True:
            try:
                check_get_steps(steps)
            except ValueError:
                print("步骤代码为整数，请重新输入")
                error = True
            if error == True:
                steps = get_step()
            elif right == len(steps):
                break
        run(steps)
        while not (check_ok()):
            run(steps)
            run_num = run_num + 1
        if check_ok():
            success = success + 1
            print("重复" + str(run_num + 1) + "次转动程序后成功，一共转动" + str((run_num + 1) * len(steps)) + "次，本次转动程序代号为" + str(
                steps))
    else:
        print("模式选择错误，重启：")
        print()
        re=1
        return
    print()
    if input("输入q结束本程序，直接回车再次运行   ---->")=='q':
        q=True
        return
while not(q) or re ==1:
    try:
        mode = input("请选择程序运行模式，魔方规律验证模式输入1，自定义转动步骤输入2      --------->")
        main_func()
    except:
        print("程序出现错误啦，程序重启：")
        print()
print("程序退出，感谢您的使用   ------@AK.Chan")
# Out:
# 输入步骤有误，请重新输入

# %%
import requests
import json
import easywebdav as w
from time import sleep
requests.adapters.DEFAULT_RETRIES = 9999999999999
def main():
    re=requests.get("https://api.lolicon.app/setu/v2?size=original&excludeAI=true")
    re=json.loads(re.text)
    print(str(re))
    name=str(re['data'][0]['pid'])
    re=re['data'][0]['urls']['original']
    name=name+"."+re["data"][0]["ext"]
    print(str(re))
    w.basestring = str
    w.client.basestring = str
    u=w.connect("app.koofr.net",username="admin@kandk.cf",password="0u30 l4px b1r1 heag",protocol='https')
    png=requests.get(re).content
    with open(name, 'wb') as f:
            f.write(png)
    print("Saved "+name,end="\n")    
    u.upload(name,"dav/tt/apipic/"+name)
    print("\n")
while True:
  try:
    main()
  except:
    while True:
      print("Connection refused by the server..")
      print("Let me sleep for 5 seconds")
      print("ZZzzzz...")
      sleep(5)
      print("Was a nice sleep, now let me continue...")
      continue
# Out:
# {'error': '', 'data': [{'pid': 95672958, 'p': 0, 'uid': 4116954, 'title': '策士ロコ', 'author': 'めんぼー', 'r18': False, 'width': 1410, 'height': 1838, 'tags': ['R-18', 'ブルーアーカイブ', '碧蓝档案', 'シロコ', '事後', '事后', '中出し', '中出', '砂狼シロコ', 'Sunaookami Shiroko', 'ゴムに穴', '破れゴム', 'ripped condom', '先生(ブルーアーカイブ)'], 'ext': 'jpg', 'aiType': 0, 'uploadDate': 1642759201000, 'urls': {'original': 'https://i.pixiv.re/img-original/img/2022/01/21/19/00/01/95672958_p0.jpg'}}]}
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_305/4264449740.py in <module>
#      24   try:
# ...

# %%
import requests
import json
import easywebdav as w
requests.adapters.DEFAULT_RETRIES = 9999999999999
while True:
    re=requests.get("https://api.lolicon.app/setu/v2?size=original&excludeAI=true")
    re=json.loads(re.text)
    print(str(re))
    name=str(re['data'][0]['pid'])
    re=re['data'][0]['urls']['original']
    name=name+".jpg"
    print(str(re))
    w.basestring = str
    w.client.basestring = str
    u=w.connect("app.koofr.net",username="admin@kandk.cf",password="0u30 l4px b1r1 heag",protocol='https')
    png=requests.get(re).content
    with open(name, 'wb') as f:
            f.write(png)
    print("Saved "+name,end="\n")    
    u.upload(name,"dav/tt/apipic/"+name)
    print("\n")
# Out:
# {'error': '', 'data': [{'pid': 69219385, 'p': 0, 'uid': 10850531, 'title': '纱雾酱', 'author': '韩信狗斌', 'r18': False, 'width': 2398, 'height': 3391, 'tags': ['萝莉', 'loli', '和泉紗霧', '和泉纱雾', '纱雾', 'エロマンガ先生', '埃罗芒阿老师', 'R-18'], 'ext': 'jpg', 'aiType': 0, 'uploadDate': 1528906795000, 'urls': {'original': 'https://i.pixiv.re/img-original/img/2018/06/14/01/19/55/69219385_p0.jpg'}}]}
# https://i.pixiv.re/img-original/img/2018/06/14/01/19/55/69219385_p0.jpg
# Saved 69219385.jpg
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in _send_until_done(self, data)
#     339             try:
# --> 340                 return self.connection.send(data)
#     341             except OpenSSL.SSL.WantWriteError:
#
# ...

# %%
# !pip install easywebdav
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for easywebdav: filename=easywebdav-1.2.0-py3-none-any.whl size=4055 sha256=0bfd0c2632650b65ff8c9ea3e8b15e036d6038e933fa092aa42adc7d48489258
#   Stored in directory: /home/aistudio/.cache/pip/wheels/ac/74/d3/45f0d2390887b6a2bfcbfa62c21dcb2501ae3e59fcd57d5351
# Successfully built easywebdav
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
u.upload(name,"dav/tt/apipic/"+name)
